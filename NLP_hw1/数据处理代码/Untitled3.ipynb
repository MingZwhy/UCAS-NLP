# %%
import os
import glob
import shutil

# %%
load_path = r'F:/novels/20newsbydate/20news-bydate-test'
files_path = glob.glob(load_path + '//*')

# %%
for files in files_path:
    txts = glob.glob(files + '//*')
    print(txts)
    for txt in txts:
        os.rename(txt, txt+'.txt')
# Out:
# ['F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53068', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53257', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53260', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53261', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53262', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53265', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53272', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53276', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53277', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53278', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53279', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53280', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53293', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53294', 'F:/novels/20newsbydate/20news-bydate-test\\alt.atheism\\53297', 'F:/novels/20newsbydat
# ...
